# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_weather_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | constitucion
# Processing Record 6 of Set 1 | tezu
# Processing Record 7 of Set 1 | vagamo
# Processing Record 8 of Set 1 | dali
# Processing Record 9 of Set 1 | hastings
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | pacific grove
# Processing Record 12 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 1 | kahului
# Processing Record 14 of Set 1 | boa vista
# Processing Record 15 of Set 1 | mahebourg
# Processing Record 16 of Set 1 | souillac
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | aklavik
# Processing Record 19 of Set 1 | beringovskiy
# Processing Record 20 of Set 1 | rolim de moura
# City not found. Skipping...
# Processing Record 21 of Set 1 | port elizabeth
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | saint anthony
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | fort nelson
# Processing Record 27 of Set 1 | belyy gorodok
# Processing Record 28 of Set 1 | chakradharpur
# Processing Record 29 of Set 1 | krasnoborsk
# Processing Record 30 of Set 1 | leningradskiy
# Processing Record 31 of Set 1 | katobu
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | arraial do cabo
# Processing Record 35 of Set 1 | mar del plata
# Processing Record 36 of Set 1 | evensk
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | port-cartier
# Processing Record 39 of Set 1 | yulara
# Processing Record 40 of Set 1 | avarua
# Processing Record 41 of Set 1 | nishihara
# Processing Record 42 of Set 1 | bambous virieux
# Processing Record 43 of Set 1 | bumba
# Processing Record 44 of Set 1 | kathu
# Processing Record 45 of Set 1 | saskylakh
# Processing Record 46 of Set 1 | nakamura
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | burriana
# Processing Record 49 of Set 1 | nikolskoye
# Processing Record 50 of Set 1 | kruisfontein
# Processing Record 1 of Set 2 | mogadishu
# Processing Record 2 of Set 2 | east london
# Processing Record 3 of Set 2 | potgietersrus
# City not found. Skipping...
# Processing Record 4 of Set 2 | enshi
# Processing Record 5 of Set 2 | pevek
# Processing Record 6 of Set 2 | chuy
# Processing Record 7 of Set 2 | bongaree
# Processing Record 8 of Set 2 | cidreira
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | torbay
# Processing Record 11 of Set 2 | georgetown
# Processing Record 12 of Set 2 | port hedland
# Processing Record 13 of Set 2 | san policarpo
# Processing Record 14 of Set 2 | andilamena
# Processing Record 15 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 2 | cabo san lucas
# Processing Record 17 of Set 2 | aksarka
# Processing Record 18 of Set 2 | pochutla
# Processing Record 19 of Set 2 | coquimbo
# Processing Record 20 of Set 2 | dikson
# Processing Record 21 of Set 2 | port hardy
# Processing Record 22 of Set 2 | carutapera
# Processing Record 23 of Set 2 | baykit
# Processing Record 24 of Set 2 | kapaa
# Processing Record 25 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | zhigansk
# Processing Record 28 of Set 2 | hondo
# Processing Record 29 of Set 2 | ginir
# Processing Record 30 of Set 2 | le vauclin
# Processing Record 31 of Set 2 | chapais
# Processing Record 32 of Set 2 | cuenca
# Processing Record 33 of Set 2 | ishinomaki
# Processing Record 34 of Set 2 | batesville
# Processing Record 35 of Set 2 | khatanga
# Processing Record 36 of Set 2 | ponta do sol
# Processing Record 37 of Set 2 | naryan-mar
# Processing Record 38 of Set 2 | simav
# Processing Record 39 of Set 2 | bengkulu
# Processing Record 40 of Set 2 | belmonte
# Processing Record 41 of Set 2 | saint george
# Processing Record 42 of Set 2 | bredasdorp
# Processing Record 43 of Set 2 | gumdag
# Processing Record 44 of Set 2 | olafsvik
# Processing Record 45 of Set 2 | tasiilaq
# Processing Record 46 of Set 2 | el tigre
# Processing Record 47 of Set 2 | atuona
# Processing Record 48 of Set 2 | winnemucca
# Processing Record 49 of Set 2 | luohe
# Processing Record 50 of Set 2 | fengcheng
# Processing Record 1 of Set 3 | murgab
# Processing Record 2 of Set 3 | samarai
# Processing Record 3 of Set 3 | ribeira grande
# Processing Record 4 of Set 3 | okhotsk
# Processing Record 5 of Set 3 | raudeberg
# Processing Record 6 of Set 3 | namibe
# Processing Record 7 of Set 3 | tautira
# Processing Record 8 of Set 3 | kirkcudbright
# Processing Record 9 of Set 3 | upernavik
# Processing Record 10 of Set 3 | braco do norte
# Processing Record 11 of Set 3 | nouadhibou
# Processing Record 12 of Set 3 | sao filipe
# Processing Record 13 of Set 3 | egvekinot
# Processing Record 14 of Set 3 | mehamn
# Processing Record 15 of Set 3 | kaitangata
# Processing Record 16 of Set 3 | muros
# Processing Record 17 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 3 | mount gambier
# Processing Record 19 of Set 3 | thompson
# Processing Record 20 of Set 3 | plettenberg bay
# Processing Record 21 of Set 3 | mouzakion
# City not found. Skipping...
# Processing Record 22 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 3 | siavonga
# Processing Record 24 of Set 3 | coahuayana
# Processing Record 25 of Set 3 | banda aceh
# Processing Record 26 of Set 3 | biloela
# Processing Record 27 of Set 3 | tornio
# Processing Record 28 of Set 3 | tuktoyaktuk
# Processing Record 29 of Set 3 | hithadhoo
# Processing Record 30 of Set 3 | soreang
# Processing Record 31 of Set 3 | petauke
# Processing Record 32 of Set 3 | ilulissat
# Processing Record 33 of Set 3 | mataram
# Processing Record 34 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 3 | klaksvik
# Processing Record 36 of Set 3 | belaya gora
# Processing Record 37 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 3 | guerrero negro
# Processing Record 39 of Set 3 | yaizu
# Processing Record 40 of Set 3 | bemidji
# Processing Record 41 of Set 3 | jamestown
# Processing Record 42 of Set 3 | lagoa
# Processing Record 43 of Set 3 | midland
# Processing Record 44 of Set 3 | barrow
# Processing Record 45 of Set 3 | boden
# Processing Record 46 of Set 3 | christchurch
# Processing Record 47 of Set 3 | bluff
# Processing Record 48 of Set 3 | phan thiet
# Processing Record 49 of Set 3 | norman wells
# Processing Record 50 of Set 3 | clyde river
# Processing Record 1 of Set 4 | carnarvon
# Processing Record 2 of Set 4 | cockburn town
# Processing Record 3 of Set 4 | hilo
# Processing Record 4 of Set 4 | manjacaze
# Processing Record 5 of Set 4 | kununurra
# Processing Record 6 of Set 4 | chokurdakh
# Processing Record 7 of Set 4 | concarneau
# Processing Record 8 of Set 4 | saint-philippe
# Processing Record 9 of Set 4 | mozarlandia
# Processing Record 10 of Set 4 | lebu
# Processing Record 11 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 12 of Set 4 | velasco ibarra
# Processing Record 13 of Set 4 | shemgang
# Processing Record 14 of Set 4 | maragogi
# Processing Record 15 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 16 of Set 4 | lavrentiya
# Processing Record 17 of Set 4 | sungurlare
# Processing Record 18 of Set 4 | novopokrovka
# Processing Record 19 of Set 4 | broome
# Processing Record 20 of Set 4 | airai
# Processing Record 21 of Set 4 | kavieng
# Processing Record 22 of Set 4 | adzope
# Processing Record 23 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 4 | sapiranga
# Processing Record 25 of Set 4 | inhambane
# Processing Record 26 of Set 4 | bethel
# Processing Record 27 of Set 4 | skelleftea
# Processing Record 28 of Set 4 | korla
# Processing Record 29 of Set 4 | lexington
# Processing Record 30 of Set 4 | kavaratti
# Processing Record 31 of Set 4 | pangoa
# Processing Record 32 of Set 4 | kodiak
# Processing Record 33 of Set 4 | caraquet
# Processing Record 34 of Set 4 | isabela
# Processing Record 35 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 4 | kikwit
# Processing Record 37 of Set 4 | puerto colombia
# Processing Record 38 of Set 4 | faya
# Processing Record 39 of Set 4 | opuwo
# Processing Record 40 of Set 4 | alice springs
# Processing Record 41 of Set 4 | alugan
# Processing Record 42 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 45 of Set 4 | myaundzha
# Processing Record 46 of Set 4 | kazanskoye
# Processing Record 47 of Set 4 | kodinsk
# Processing Record 48 of Set 4 | praxedis guerrero
# Processing Record 49 of Set 4 | castro
# Processing Record 50 of Set 4 | auka
# Processing Record 1 of Set 5 | visby
# Processing Record 2 of Set 5 | udachnyy
# Processing Record 3 of Set 5 | hermanus
# Processing Record 4 of Set 5 | comodoro rivadavia
# Processing Record 5 of Set 5 | tiksi
# Processing Record 6 of Set 5 | nova olimpia
# Processing Record 7 of Set 5 | ponta delgada
# Processing Record 8 of Set 5 | ust-koksa
# Processing Record 9 of Set 5 | sao joao da barra
# Processing Record 10 of Set 5 | kuching
# Processing Record 11 of Set 5 | george town
# Processing Record 12 of Set 5 | portland
# Processing Record 13 of Set 5 | atambua
# Processing Record 14 of Set 5 | lasa
# Processing Record 15 of Set 5 | newark
# Processing Record 16 of Set 5 | ambilobe
# Processing Record 17 of Set 5 | saint-joseph
# Processing Record 18 of Set 5 | roma
# Processing Record 19 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 20 of Set 5 | san cristobal
# Processing Record 21 of Set 5 | hasaki
# Processing Record 22 of Set 5 | bilma
# Processing Record 23 of Set 5 | komsomolskiy
# Processing Record 24 of Set 5 | mahajanga
# Processing Record 25 of Set 5 | new norfolk
# Processing Record 26 of Set 5 | plymouth
# Processing Record 27 of Set 5 | geraldton
# Processing Record 28 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 29 of Set 5 | antofagasta
# Processing Record 30 of Set 5 | matagami
# Processing Record 31 of Set 5 | fortuna
# Processing Record 32 of Set 5 | cherdyn
# Processing Record 33 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 34 of Set 5 | aldan
# Processing Record 35 of Set 5 | lokosovo
# Processing Record 36 of Set 5 | yuanping
# Processing Record 37 of Set 5 | gobabis
# Processing Record 38 of Set 5 | santa cruz
# Processing Record 39 of Set 5 | payson
# Processing Record 40 of Set 5 | phrai bung
# City not found. Skipping...
# Processing Record 41 of Set 5 | sola
# Processing Record 42 of Set 5 | dukat
# Processing Record 43 of Set 5 | gouyave
# Processing Record 44 of Set 5 | belomorsk
# Processing Record 45 of Set 5 | ambulu
# Processing Record 46 of Set 5 | lorengau
# Processing Record 47 of Set 5 | abu dhabi
# Processing Record 48 of Set 5 | ginda
# Processing Record 49 of Set 5 | chikodi
# Processing Record 50 of Set 5 | dicabisagan
# Processing Record 1 of Set 6 | cambara
# Processing Record 2 of Set 6 | grindavik
# Processing Record 3 of Set 6 | nanyamba
# Processing Record 4 of Set 6 | saint-augustin
# Processing Record 5 of Set 6 | codrington
# Processing Record 6 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 6 | la ronge
# Processing Record 8 of Set 6 | virginia beach
# Processing Record 9 of Set 6 | port lincoln
# Processing Record 10 of Set 6 | churapcha
# Processing Record 11 of Set 6 | provideniya
# Processing Record 12 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 6 | yar-sale
# Processing Record 14 of Set 6 | semnan
# Processing Record 15 of Set 6 | madang
# Processing Record 16 of Set 6 | sayyan
# Processing Record 17 of Set 6 | saldanha
# Processing Record 18 of Set 6 | mahibadhoo
# Processing Record 19 of Set 6 | hede
# Processing Record 20 of Set 6 | vung tau
# Processing Record 21 of Set 6 | tucuman
# Processing Record 22 of Set 6 | linxia
# Processing Record 23 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 6 | alibag
# Processing Record 25 of Set 6 | alegrete
# Processing Record 26 of Set 6 | haines junction
# Processing Record 27 of Set 6 | sulangan
# Processing Record 28 of Set 6 | birin
# Processing Record 29 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 6 | sitka
# Processing Record 31 of Set 6 | quelimane
# Processing Record 32 of Set 6 | severo-kurilsk
# Processing Record 33 of Set 6 | atbasar
# Processing Record 34 of Set 6 | mount isa
# Processing Record 35 of Set 6 | jintur
# Processing Record 36 of Set 6 | port moresby
# Processing Record 37 of Set 6 | gao
# Processing Record 38 of Set 6 | camargo
# Processing Record 39 of Set 6 | kamaishi
# Processing Record 40 of Set 6 | yaan
# Processing Record 41 of Set 6 | yakeshi
# Processing Record 42 of Set 6 | touros
# Processing Record 43 of Set 6 | uberaba
# Processing Record 44 of Set 6 | cayenne
# Processing Record 45 of Set 6 | northam
# Processing Record 46 of Set 6 | sept-iles
# Processing Record 47 of Set 6 | kapuskasing
# Processing Record 48 of Set 6 | starogard gdanski
# Processing Record 49 of Set 6 | taoudenni
# Processing Record 50 of Set 6 | bontang
# Processing Record 1 of Set 7 | oranjemund
# Processing Record 2 of Set 7 | balkanabat
# Processing Record 3 of Set 7 | luderitz
# Processing Record 4 of Set 7 | esperance
# Processing Record 5 of Set 7 | saint-donat-de-montcalm
# Processing Record 6 of Set 7 | san quintin
# Processing Record 7 of Set 7 | qandahar
# City not found. Skipping...
# Processing Record 8 of Set 7 | policka
# Processing Record 9 of Set 7 | fairbanks
# Processing Record 10 of Set 7 | pafos
# Processing Record 11 of Set 7 | kuytun
# Processing Record 12 of Set 7 | dingle
# Processing Record 13 of Set 7 | salalah
# Processing Record 14 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 7 | anadyr
# Processing Record 16 of Set 7 | swift current
# Processing Record 17 of Set 7 | znin
# Processing Record 18 of Set 7 | bara
# Processing Record 19 of Set 7 | kysyl-syr
# Processing Record 20 of Set 7 | adrar
# Processing Record 21 of Set 7 | ketchikan
# Processing Record 22 of Set 7 | lata
# Processing Record 23 of Set 7 | turukhansk
# Processing Record 24 of Set 7 | puerto maldonado
# Processing Record 25 of Set 7 | bourail
# Processing Record 26 of Set 7 | ancud
# Processing Record 27 of Set 7 | sibut
# Processing Record 28 of Set 7 | thessalon
# Processing Record 29 of Set 7 | cherskiy
# Processing Record 30 of Set 7 | faanui
# Processing Record 31 of Set 7 | itarema
# Processing Record 32 of Set 7 | juegang
# Processing Record 33 of Set 7 | awbari
# Processing Record 34 of Set 7 | tukrah
# Processing Record 35 of Set 7 | bolu
# Processing Record 36 of Set 7 | balabac
# Processing Record 37 of Set 7 | victoria
# Processing Record 38 of Set 7 | prince rupert
# Processing Record 39 of Set 7 | krasnogorskoye
# Processing Record 40 of Set 7 | meadow lake
# Processing Record 41 of Set 7 | santa rosa
# Processing Record 42 of Set 7 | iqaluit
# Processing Record 43 of Set 7 | millinocket
# Processing Record 44 of Set 7 | vestnes
# Processing Record 45 of Set 7 | lastoursville
# Processing Record 46 of Set 7 | denpasar
# Processing Record 47 of Set 7 | asayita
# City not found. Skipping...
# Processing Record 48 of Set 7 | nichinan
# Processing Record 49 of Set 7 | henties bay
# Processing Record 50 of Set 7 | miyazu
# Processing Record 1 of Set 8 | yantzaza
# Processing Record 2 of Set 8 | kapit
# Processing Record 3 of Set 8 | hambantota
# Processing Record 4 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 5 of Set 8 | soubre
# Processing Record 6 of Set 8 | kashi
# Processing Record 7 of Set 8 | mountain home
# Processing Record 8 of Set 8 | puerto escondido
# Processing Record 9 of Set 8 | amapa
# Processing Record 10 of Set 8 | vila franca do campo
# Processing Record 11 of Set 8 | veraval
# Processing Record 12 of Set 8 | tiarei
# Processing Record 13 of Set 8 | tessalit
# Processing Record 14 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 8 | rognedino
# Processing Record 16 of Set 8 | tateyama
# Processing Record 17 of Set 8 | novyy urengoy
# Processing Record 18 of Set 8 | mackay
# Processing Record 19 of Set 8 | durgapur
# Processing Record 20 of Set 8 | haukipudas
# Processing Record 21 of Set 8 | gudiyattam
# City not found. Skipping...
# Processing Record 22 of Set 8 | tuatapere
# Processing Record 23 of Set 8 | tyrma
# Processing Record 24 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 8 | muisne
# Processing Record 26 of Set 8 | paidha
# Processing Record 27 of Set 8 | pandamatenga
# Processing Record 28 of Set 8 | englehart
# Processing Record 29 of Set 8 | bolotnoye
# Processing Record 30 of Set 8 | murovane
# Processing Record 31 of Set 8 | rio cauto
# Processing Record 32 of Set 8 | margate
# Processing Record 33 of Set 8 | bathsheba
# Processing Record 34 of Set 8 | teluknaga
# Processing Record 35 of Set 8 | gazanjyk
# Processing Record 36 of Set 8 | coihueco
# Processing Record 37 of Set 8 | andros town
# Processing Record 38 of Set 8 | medina
# Processing Record 39 of Set 8 | hovd
# Processing Record 40 of Set 8 | russell
# Processing Record 41 of Set 8 | luwingu
# Processing Record 42 of Set 8 | iquique
# Processing Record 43 of Set 8 | nanortalik
# Processing Record 44 of Set 8 | qazanbulaq
# Processing Record 45 of Set 8 | bivolari
# Processing Record 46 of Set 8 | vao
# Processing Record 47 of Set 8 | kushmurun
# Processing Record 48 of Set 8 | whitehorse
# Processing Record 49 of Set 8 | carballo
# Processing Record 50 of Set 8 | hamilton
# Processing Record 1 of Set 9 | inta
# Processing Record 2 of Set 9 | unai
# Processing Record 3 of Set 9 | lanxi
# Processing Record 4 of Set 9 | shihezi
# Processing Record 5 of Set 9 | collie
# Processing Record 6 of Set 9 | gweta
# Processing Record 7 of Set 9 | ajdabiya
# Processing Record 8 of Set 9 | san pedro de ycuamandiyu
# Processing Record 9 of Set 9 | hudson bay
# Processing Record 10 of Set 9 | nome
# Processing Record 11 of Set 9 | beian
# Processing Record 12 of Set 9 | umm kaddadah
# Processing Record 13 of Set 9 | port-gentil
# Processing Record 14 of Set 9 | shenkursk
# Processing Record 15 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 9 | hami
# Processing Record 17 of Set 9 | matara
# Processing Record 18 of Set 9 | rawson
# Processing Record 19 of Set 9 | galeana
# Processing Record 20 of Set 9 | dhadar
# Processing Record 21 of Set 9 | arroyo
# Processing Record 22 of Set 9 | tarko-sale
# Processing Record 23 of Set 9 | mollendo
# Processing Record 24 of Set 9 | muyezerskiy
# Processing Record 25 of Set 9 | katsuura
# Processing Record 26 of Set 9 | waterloo
# Processing Record 27 of Set 9 | tombouctou
# Processing Record 28 of Set 9 | sirvintos
# Processing Record 29 of Set 9 | agadir
# Processing Record 30 of Set 9 | guilin
# Processing Record 31 of Set 9 | zaysan
# Processing Record 32 of Set 9 | poletayevo
# Processing Record 33 of Set 9 | dudinka
# Processing Record 34 of Set 9 | khormuj
# City not found. Skipping...
# Processing Record 35 of Set 9 | kyzyl-suu
# Processing Record 36 of Set 9 | panzhihua
# Processing Record 37 of Set 9 | hervey bay
# Processing Record 38 of Set 9 | kirakira
# Processing Record 39 of Set 9 | rafai
# Processing Record 40 of Set 9 | finnsnes
# Processing Record 41 of Set 9 | sisimiut
# Processing Record 42 of Set 9 | tokat
# Processing Record 43 of Set 9 | sakakah
# Processing Record 44 of Set 9 | atar
# Processing Record 45 of Set 9 | huambo
# Processing Record 46 of Set 9 | singaraja
# Processing Record 47 of Set 9 | alexandria
# Processing Record 48 of Set 9 | gayny
# Processing Record 49 of Set 9 | boguchany
# Processing Record 50 of Set 9 | middelburg
# Processing Record 1 of Set 10 | martapura
# Processing Record 2 of Set 10 | yerbogachen
# Processing Record 3 of Set 10 | buin
# Processing Record 4 of Set 10 | raxaul
# Processing Record 5 of Set 10 | morristown
# Processing Record 6 of Set 10 | warwick
# Processing Record 7 of Set 10 | koronowo
# Processing Record 8 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 9 of Set 10 | iwade
# Processing Record 10 of Set 10 | roald
# Processing Record 11 of Set 10 | melfi
# Processing Record 12 of Set 10 | abilene
# Processing Record 13 of Set 10 | qasigiannguit
# Processing Record 14 of Set 10 | araouane
# Processing Record 15 of Set 10 | obama
# Processing Record 16 of Set 10 | carbonia
# Processing Record 17 of Set 10 | beloha
# Processing Record 18 of Set 10 | port macquarie
# Processing Record 19 of Set 10 | palmer
# Processing Record 20 of Set 10 | ibra
# Processing Record 21 of Set 10 | biak
# Processing Record 22 of Set 10 | mahanje
# Processing Record 23 of Set 10 | khilok
# Processing Record 24 of Set 10 | haapiti
# Processing Record 25 of Set 10 | shimoda
# Processing Record 26 of Set 10 | cururupu
# Processing Record 27 of Set 10 | bahia blanca
# Processing Record 28 of Set 10 | ternate
# Processing Record 29 of Set 10 | arlit
# Processing Record 30 of Set 10 | xichang
# Processing Record 31 of Set 10 | paamiut
# Processing Record 32 of Set 10 | longyearbyen
# Processing Record 33 of Set 10 | kendari
# Processing Record 34 of Set 10 | pisco
# Processing Record 35 of Set 10 | grande-riviere
# City not found. Skipping...
# Processing Record 36 of Set 10 | port augusta
# Processing Record 37 of Set 10 | znamenka
# Processing Record 38 of Set 10 | kloulklubed
# Processing Record 39 of Set 10 | lompoc
# Processing Record 40 of Set 10 | port blair
# Processing Record 41 of Set 10 | sabha
# Processing Record 42 of Set 10 | fuerte
# Processing Record 43 of Set 10 | asind
# Processing Record 44 of Set 10 | gaoua
# Processing Record 45 of Set 10 | san patricio
# Processing Record 46 of Set 10 | trelew
# Processing Record 47 of Set 10 | saurimo
# Processing Record 48 of Set 10 | tura
# Processing Record 49 of Set 10 | rameshki
# Processing Record 50 of Set 10 | kushima
# Processing Record 1 of Set 11 | odweyne
# Processing Record 2 of Set 11 | isangel
# Processing Record 3 of Set 11 | isiro
# Processing Record 4 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 5 of Set 11 | zholymbet
# Processing Record 6 of Set 11 | chandbali
# Processing Record 7 of Set 11 | college
# Processing Record 8 of Set 11 | conakry
# Processing Record 9 of Set 11 | tromso
# Processing Record 10 of Set 11 | husavik
# Processing Record 11 of Set 11 | nata
# Processing Record 12 of Set 11 | smoky lake
# Processing Record 13 of Set 11 | sinnamary
# Processing Record 14 of Set 11 | glencoe
# Processing Record 15 of Set 11 | talaya
# Processing Record 16 of Set 11 | prince albert
# Processing Record 17 of Set 11 | kamina
# Processing Record 18 of Set 11 | khorinsk
# Processing Record 19 of Set 11 | thomasville
# Processing Record 20 of Set 11 | evansville
# Processing Record 21 of Set 11 | tamworth
# Processing Record 22 of Set 11 | palana
# Processing Record 23 of Set 11 | sur
# Processing Record 24 of Set 11 | gazni
# City not found. Skipping...
# Processing Record 25 of Set 11 | vila velha
# Processing Record 26 of Set 11 | morondava
# Processing Record 27 of Set 11 | algiers
# Processing Record 28 of Set 11 | jacareacanga
# Processing Record 29 of Set 11 | leutkirch
# Processing Record 30 of Set 11 | vostok
# Processing Record 31 of Set 11 | waitati
# Processing Record 32 of Set 11 | nelson bay
# Processing Record 33 of Set 11 | sechura
# Processing Record 34 of Set 11 | pingliang
# Processing Record 35 of Set 11 | avera
# Processing Record 36 of Set 11 | saint-pierre
# Processing Record 37 of Set 11 | charlton
# Processing Record 38 of Set 11 | ahipara
# Processing Record 39 of Set 11 | imperia
# Processing Record 40 of Set 11 | sao jose da coroa grande
# Processing Record 41 of Set 11 | dir
# Processing Record 42 of Set 11 | jurado
# Processing Record 43 of Set 11 | kotdwara
# Processing Record 44 of Set 11 | elko
# Processing Record 45 of Set 11 | saravan
# Processing Record 46 of Set 11 | ilinskiy
# Processing Record 47 of Set 11 | outlook
# Processing Record 48 of Set 11 | nizhniy tsasuchey
# Processing Record 49 of Set 11 | pavlohrad
# Processing Record 50 of Set 11 | yenangyaung
# Processing Record 1 of Set 12 | ulverstone
# Processing Record 2 of Set 12 | manaure
# Processing Record 3 of Set 12 | katima mulilo
# Processing Record 4 of Set 12 | tabou
# Processing Record 5 of Set 12 | micheweni
# Processing Record 6 of Set 12 | maniitsoq
# Processing Record 7 of Set 12 | nelipyno
# Processing Record 8 of Set 12 | dwarka
# Processing Record 9 of Set 12 | ostrovnoy
# Processing Record 10 of Set 12 | tigil
# Processing Record 11 of Set 12 | port pirie
# Processing Record 12 of Set 12 | dangtu
# Processing Record 13 of Set 12 | zhuozhou
# City not found. Skipping...
# Processing Record 14 of Set 12 | viedma
# Processing Record 15 of Set 12 | batticaloa
# Processing Record 16 of Set 12 | thabazimbi
# Processing Record 17 of Set 12 | dunedin
# Processing Record 18 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 12 | arroio do meio
# Processing Record 21 of Set 12 | cap malheureux
# Processing Record 22 of Set 12 | anito
# Processing Record 23 of Set 12 | khasan
# Processing Record 24 of Set 12 | yomitan
# City not found. Skipping...
# Processing Record 25 of Set 12 | cam ranh
# Processing Record 26 of Set 12 | broken hill
# Processing Record 27 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 12 | nongstoin
# Processing Record 29 of Set 12 | san rafael del sur
# Processing Record 30 of Set 12 | beira
# Processing Record 31 of Set 12 | entre rios
# Processing Record 32 of Set 12 | nador
# Processing Record 33 of Set 12 | balsas
# Processing Record 34 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 35 of Set 12 | duki
# Processing Record 36 of Set 12 | riyadh
# Processing Record 37 of Set 12 | ambon
# Processing Record 38 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 12 | tamandare
# Processing Record 40 of Set 12 | hualmay
# Processing Record 41 of Set 12 | tir pol
# City not found. Skipping...
# Processing Record 42 of Set 12 | burica
# City not found. Skipping...
# Processing Record 43 of Set 12 | juifang
# City not found. Skipping...
# Processing Record 44 of Set 12 | sar-e pul
# Processing Record 45 of Set 12 | westport
# Processing Record 46 of Set 12 | panjab
# Processing Record 47 of Set 12 | fillmore
# Processing Record 48 of Set 12 | lumsden
# Processing Record 49 of Set 12 | voh
# Processing Record 50 of Set 12 | ilhabela
# Processing Record 1 of Set 13 | sueyoshi
# Processing Record 2 of Set 13 | camacha
# Processing Record 3 of Set 13 | aden
# Processing Record 4 of Set 13 | tilichiki
# Processing Record 5 of Set 13 | polovinnoye
# Processing Record 6 of Set 13 | berlevag
# Processing Record 7 of Set 13 | carnot
# Processing Record 8 of Set 13 | thilogne
# City not found. Skipping...
# Processing Record 9 of Set 13 | yokadouma
# Processing Record 10 of Set 13 | staraya poltavka
# Processing Record 11 of Set 13 | baruun-urt
# Processing Record 12 of Set 13 | harper
# Processing Record 13 of Set 13 | cascais
# Processing Record 14 of Set 13 | kindu
# Processing Record 15 of Set 13 | port hueneme
# Processing Record 16 of Set 13 | novaci
# Processing Record 17 of Set 13 | kalmunai
# Processing Record 18 of Set 13 | pacifica
# Processing Record 19 of Set 13 | marshall
# Processing Record 20 of Set 13 | flinders
# Processing Record 21 of Set 13 | rafaela
# Processing Record 22 of Set 13 | obera
# Processing Record 23 of Set 13 | yanam
# Processing Record 24 of Set 13 | nguruka
# Processing Record 25 of Set 13 | bonthe
# Processing Record 26 of Set 13 | bereznik
# Processing Record 27 of Set 13 | cabedelo
# Processing Record 28 of Set 13 | linhares
# Processing Record 29 of Set 13 | gasa
# Processing Record 30 of Set 13 | shimoni
# Processing Record 31 of Set 13 | los llanos de aridane
# Processing Record 32 of Set 13 | dehui
# Processing Record 33 of Set 13 | pangnirtung
# Processing Record 34 of Set 13 | talnakh
# Processing Record 35 of Set 13 | vila do maio
# Processing Record 36 of Set 13 | wenceslau braz
# Processing Record 37 of Set 13 | ramsgate
# Processing Record 38 of Set 13 | bani walid
# Processing Record 39 of Set 13 | caravelas
# Processing Record 40 of Set 13 | mineiros
# Processing Record 41 of Set 13 | matias romero
# Processing Record 42 of Set 13 | linkou
# Processing Record 43 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 44 of Set 13 | hay river
# Processing Record 45 of Set 13 | ostroleka
# Processing Record 46 of Set 13 | safaga
# Processing Record 47 of Set 13 | san cosme y damian
# Processing Record 48 of Set 13 | aktau
# Processing Record 49 of Set 13 | luciu
# Processing Record 50 of Set 13 | jiaozuo
# Processing Record 1 of Set 14 | krasnogorodsk
# Processing Record 2 of Set 14 | srednekolymsk
# Processing Record 3 of Set 14 | puquio
# Processing Record 4 of Set 14 | paragominas
# Processing Record 5 of Set 14 | rosetta
# Processing Record 6 of Set 14 | homer
# Processing Record 7 of Set 14 | luganville
# Processing Record 8 of Set 14 | shellbrook
# Processing Record 9 of Set 14 | madras
# Processing Record 10 of Set 14 | sulecin
# Processing Record 11 of Set 14 | gazojak
# Processing Record 12 of Set 14 | barkhan
# Processing Record 13 of Set 14 | sawakin
# Processing Record 14 of Set 14 | sakaiminato
# Processing Record 15 of Set 14 | vanimo
# Processing Record 16 of Set 14 | ust-nera
# Processing Record 17 of Set 14 | ndola
# Processing Record 18 of Set 14 | indianola
# Processing Record 19 of Set 14 | kaeo
# Processing Record 20 of Set 14 | kichera
# Processing Record 21 of Set 14 | te anau
# Processing Record 22 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 24 of Set 14 | charters towers
# Processing Record 25 of Set 14 | dostpur
# Processing Record 26 of Set 14 | mandan
# Processing Record 27 of Set 14 | graciano sanchez
# Processing Record 28 of Set 14 | tahe
# Processing Record 29 of Set 14 | praia
# Processing Record 30 of Set 14 | poum
# Processing Record 31 of Set 14 | atwater
# Processing Record 32 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 33 of Set 14 | catuday
# Processing Record 34 of Set 14 | lethem
# Processing Record 35 of Set 14 | pak phanang
# Processing Record 36 of Set 14 | ugoofaaru
# Processing Record 37 of Set 14 | weatherford
# Processing Record 38 of Set 14 | pervomayskoye
# Processing Record 39 of Set 14 | chicama
# Processing Record 40 of Set 14 | drugovo
# Processing Record 41 of Set 14 | porto novo
# Processing Record 42 of Set 14 | hailar
# Processing Record 43 of Set 14 | verkhniy baskunchak
# Processing Record 44 of Set 14 | gazli
# Processing Record 45 of Set 14 | benghazi
# Processing Record 46 of Set 14 | jose de freitas
# Processing Record 47 of Set 14 | iturama
# Processing Record 48 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 49 of Set 14 | suarez
# Processing Record 50 of Set 14 | kangaatsiaq
# Processing Record 1 of Set 15 | adre
# Processing Record 2 of Set 15 | nemuro
# Processing Record 3 of Set 15 | sapouy
# Processing Record 4 of Set 15 | marzuq
# Processing Record 5 of Set 15 | dalbandin
# Processing Record 6 of Set 15 | cartagena del chaira
# Processing Record 7 of Set 15 | tongliao
# Processing Record 8 of Set 15 | tapaua
# City not found. Skipping...
# Processing Record 9 of Set 15 | aguimes
# Processing Record 10 of Set 15 | gornopravdinsk
# Processing Record 11 of Set 15 | clinton
# Processing Record 12 of Set 15 | krasnooktyabrskiy
# Processing Record 13 of Set 15 | beypur
# City not found. Skipping...
# Processing Record 14 of Set 15 | horta
# Processing Record 15 of Set 15 | bonavista
# Processing Record 16 of Set 15 | sterling
# Processing Record 17 of Set 15 | urumqi
# Processing Record 18 of Set 15 | verkhnevilyuysk
# Processing Record 19 of Set 15 | akyab
# Processing Record 20 of Set 15 | leh
# Processing Record 21 of Set 15 | abha
# Processing Record 22 of Set 15 | kazminskoye
# City not found. Skipping...
# Processing Record 23 of Set 15 | trebic
# Processing Record 24 of Set 15 | tunceli
# Processing Record 25 of Set 15 | crestline
# Processing Record 26 of Set 15 | padang
# Processing Record 27 of Set 15 | kaka
# Processing Record 28 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 29 of Set 15 | bababe
# City not found. Skipping...
# Processing Record 30 of Set 15 | marystown
# Processing Record 31 of Set 15 | acapulco
# Processing Record 32 of Set 15 | laguna
# Processing Record 33 of Set 15 | lae
# Processing Record 34 of Set 15 | anupgarh
# Processing Record 35 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 15 | bubaque
# Processing Record 37 of Set 15 | yurimaguas
# Processing Record 38 of Set 15 | lgov
# Processing Record 39 of Set 15 | trairi
# Processing Record 40 of Set 15 | halifax
# Processing Record 41 of Set 15 | arman
# Processing Record 42 of Set 15 | dhuwaran
# Processing Record 43 of Set 15 | vardo
# Processing Record 44 of Set 15 | ca mau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 684

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0  Punta Arenas -53.1500  -70.9167           clear sky     53.71        50
# 1       Qaanaaq  77.4840  -69.3632     overcast clouds     11.91        65
# 2       Ushuaia -54.8000  -68.3000           clear sky     56.86        41
# 3     Cape Town -33.9258   18.4232          few clouds     65.08        70
# 4  Constitucion -35.3333  -72.4167     overcast clouds     59.14        76
# 5          Tezu  27.9167   96.1667     overcast clouds     68.54        51
# 6        Vagamo  61.8751    9.0967     overcast clouds     38.50        87
# 7          Dali  25.7000  100.1833           clear sky     51.80        87
# 8      Hastings  50.8552    0.5729           clear sky     55.15        62
# 9        Albany  42.6001  -73.9662     overcast clouds     60.94        80
#
#    Cloudiness  Wind Speed Country
# 0           0        9.22      CL
# 1         100        9.40      GL
# 2           0        0.00      AR
# 3          20        5.75      ZA
# 4         100        5.32      CL
# 5          94        3.94      IN
# 6         100        3.36      NO
# 7           0        3.76      CN
# 8           2       29.53      GB
# 9         100       11.03      US

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas      CL -53.1500  -70.9167     53.71        50           0
# 1       Qaanaaq      GL  77.4840  -69.3632     11.91        65         100
# 2       Ushuaia      AR -54.8000  -68.3000     56.86        41           0
# 3     Cape Town      ZA -33.9258   18.4232     65.08        70          20
# 4  Constitucion      CL -35.3333  -72.4167     59.14        76         100
# 5          Tezu      IN  27.9167   96.1667     68.54        51          94
# 6        Vagamo      NO  61.8751    9.0967     38.50        87         100
# 7          Dali      CN  25.7000  100.1833     51.80        87           0
# 8      Hastings      GB  50.8552    0.5729     55.15        62           2
# 9        Albany      US  42.6001  -73.9662     60.94        80         100
#
#    Wind Speed Current Description
# 0        9.22           clear sky
# 1        9.40     overcast clouds
# 2        0.00           clear sky
# 3        5.75          few clouds
# 4        5.32     overcast clouds
# 5        3.94     overcast clouds
# 6        3.36     overcast clouds
# 7        3.76           clear sky
# 8       29.53           clear sky
# 9       11.03     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
